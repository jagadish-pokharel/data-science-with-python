# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\L E N O V O\OneDrive\Desktop\datas\archive\onlinefoods.csv")
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.isnull().sum()
import numpy as np

# %%
for _ in range(5):
    jp=np.random.randint(0,100)
    df['Monthly Income'][jp]=None
# Out:
# C:\Users\L E N O V O\AppData\Local\Temp\ipykernel_17148\4027867746.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Monthly Income'][jp]=None
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                5
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df['Marital Status']=df['Marital Status'].map({'Single':1,'Married':0})

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation  Monthly Income  \
# 0   20  Female             1.0    Student       No Income
# 1   24  Female             1.0    Student  Below Rs.10000
# 2   22    Male             1.0    Student  Below Rs.10000
# 3   22  Female             1.0    Student       No Income
# 4   22    Male             1.0    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.tail()
# Out:
#      Age  Gender  Marital Status Occupation  Monthly Income  \
# 383   23  Female             1.0    Student       No Income
# 384   23  Female             1.0    Student       No Income
# 385   22  Female             1.0    Student       No Income
# 386   23    Male             1.0    Student  Below Rs.10000
# 387   23    Male             1.0    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.drop(['Unnamed: 12','Educational Qualifications'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation  Monthly Income  Family size  \
# 0   20  Female             1.0    Student       No Income            4
# 1   24  Female             1.0    Student  Below Rs.10000            3
# 2   22    Male             1.0    Student  Below Rs.10000            3
# 3   22  Female             1.0    Student       No Income            6
# 4   22    Male             1.0    Student  Below Rs.10000            4
#
#    latitude  longitude  Pin code Output   Feedback
# 0   12.9766    77.5993    560001    Yes   Positive
# 1   12.9770    77.5773    560009    Yes   Positive
# 2   12.9551    77.6593    560017    Yes  Negative
# 3   12.9473    77.5616    560019    Yes   Positive
# 4   12.9850    77.5533    560010    Yes   Positive

# %%
df.drop(['Pin code','Output'],axis='columns')
# Out:
#      Age  Gender  Marital Status Occupation  Monthly Income  Family size  \
# 0     20  Female             1.0    Student       No Income            4
# 1     24  Female             1.0    Student  Below Rs.10000            3
# 2     22    Male             1.0    Student  Below Rs.10000            3
# 3     22  Female             1.0    Student       No Income            6
# 4     22    Male             1.0    Student  Below Rs.10000            4
# ..   ...     ...             ...        ...             ...          ...
# 383   23  Female             1.0    Student       No Income            2
# 384   23  Female             1.0    Student       No Income            4
# 385   22  Female             1.0    Student       No Income            5
# 386   23    Male             1.0    Student  Below Rs.10000            2
# 387   23    Male             1.0    Student       No Income            5
#
#      latitude  longitude   Feedback
# 0     12.9766    77.5993   Positive
# ...

# %%
df['Feedback']=df['Feedback'].map({'Positive':1,'Negative':0})

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation  Monthly Income  Family size  \
# 0   20  Female             1.0    Student       No Income            4
# 1   24  Female             1.0    Student  Below Rs.10000            3
# 2   22    Male             1.0    Student  Below Rs.10000            3
# 3   22  Female             1.0    Student       No Income            6
# 4   22    Male             1.0    Student  Below Rs.10000            4
#
#    latitude  longitude  Pin code Output  Feedback
# 0   12.9766    77.5993    560001    Yes       1.0
# 1   12.9770    77.5773    560009    Yes       1.0
# 2   12.9551    77.6593    560017    Yes       NaN
# 3   12.9473    77.5616    560019    Yes       1.0
# 4   12.9850    77.5533    560010    Yes       1.0

# %%
df.drop_duplicates()
# Out:
#      Age  Gender  Marital Status Occupation   Monthly Income  Family size  \
# 0     20  Female             1.0    Student        No Income            4
# 1     24  Female             1.0    Student   Below Rs.10000            3
# 2     22    Male             1.0    Student   Below Rs.10000            3
# 3     22  Female             1.0    Student        No Income            6
# 4     22    Male             1.0    Student   Below Rs.10000            4
# ..   ...     ...             ...        ...              ...          ...
# 355   21    Male             1.0    Student        No Income            2
# 363   31    Male             0.0   Employee  More than 50000            3
# 369   30    Male             0.0   Employee  More than 50000            6
# 374   21    Male             1.0    Student        No Income            3
# 386   23    Male             1.0    Student   Below Rs.10000            2
#
#      latitude  longitude  Pin code Output  Feedback
# ...

# %%
df.dropna(subset=['Feedback'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation   Monthly Income  Family size  \
# 0   20  Female             1.0    Student        No Income            4
# 1   24  Female             1.0    Student   Below Rs.10000            3
# 3   22  Female             1.0    Student        No Income            6
# 4   22    Male             1.0    Student   Below Rs.10000            4
# 5   27  Female             0.0   Employee  More than 50000            2
#
#    latitude  longitude  Pin code Output  Feedback
# 0   12.9766    77.5993    560001    Yes       1.0
# 1   12.9770    77.5773    560009    Yes       1.0
# 3   12.9473    77.5616    560019    Yes       1.0
# 4   12.9850    77.5533    560010    Yes       1.0
# 5   12.9299    77.6848    560103    Yes       1.0

# %%
df['Gender']=df['Gender'].map({'Female':0,'Male':1})

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation   Monthly Income  Family size  \
# 0   20       0             1.0    Student        No Income            4
# 1   24       0             1.0    Student   Below Rs.10000            3
# 3   22       0             1.0    Student        No Income            6
# 4   22       1             1.0    Student   Below Rs.10000            4
# 5   27       0             0.0   Employee  More than 50000            2
#
#    latitude  longitude  Pin code Output  Feedback
# 0   12.9766    77.5993    560001    Yes       1.0
# 1   12.9770    77.5773    560009    Yes       1.0
# 3   12.9473    77.5616    560019    Yes       1.0
# 4   12.9850    77.5533    560010    Yes       1.0
# 5   12.9299    77.6848    560103    Yes       1.0

# %%
df.dropna(subset=['Output','Occupation'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Marital Status Occupation   Monthly Income  Family size  \
# 0   20       0             1.0    Student        No Income            4
# 1   24       0             1.0    Student   Below Rs.10000            3
# 3   22       0             1.0    Student        No Income            6
# 4   22       1             1.0    Student   Below Rs.10000            4
# 5   27       0             0.0   Employee  More than 50000            2
#
#    latitude  longitude  Pin code Output  Feedback
# 0   12.9766    77.5993    560001    Yes       1.0
# 1   12.9770    77.5773    560009    Yes       1.0
# 3   12.9473    77.5616    560019    Yes       1.0
# 4   12.9850    77.5533    560010    Yes       1.0
# 5   12.9299    77.6848    560103    Yes       1.0

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
df['Occupation']=encoder.fit_transform(df[['Occupation']])
df['Output']=encoder.fit_transform(df[['Output']])

# %%
df.head()
# Out:
#    Age  Gender  Marital Status  Occupation   Monthly Income  Family size  \
# 0   20       0             1.0         3.0        No Income            4
# 1   24       0             1.0         3.0   Below Rs.10000            3
# 3   22       0             1.0         3.0        No Income            6
# 4   22       1             1.0         3.0   Below Rs.10000            4
# 5   27       0             0.0         0.0  More than 50000            2
#
#    latitude  longitude  Pin code  Output  Feedback
# 0   12.9766    77.5993    560001     0.0       1.0
# 1   12.9770    77.5773    560009     0.0       1.0
# 3   12.9473    77.5616    560019     0.0       1.0
# 4   12.9850    77.5533    560010     0.0       1.0
# 5   12.9299    77.6848    560103     0.0       1.0
